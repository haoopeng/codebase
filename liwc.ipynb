# %%
import pickle

# %%
with open('./LIWC.pkl', 'rb') as liwc:
    int_cate, liwc = pickle.load(liwc)

# %%
int_cate
# Out:
# {1: 'function (Function Words)',
#  2: 'pronoun (Pronouns)',
#  3: 'ppron (Personal Pronouns)',
#  4: 'i (I)',
#  5: 'we (We)',
#  6: 'you (You)',
#  7: 'shehe (SheHe)',
#  8: 'they (They)',
#  9: 'ipron (Impersonal Pronouns)',
#  10: 'article (Articles)',
#  11: 'prep (Prepositions)',
#  12: 'auxverb (Auxiliary Verbs)',
#  13: 'adverb (Adverbs)',
#  14: 'conj (Conjunctions)',
#  15: 'negate (Negations)',
#  20: 'verb (Verbs)',
#  21: 'adj (Adjectives)',
#  22: 'compare (Comparisons)',
#  23: 'interrog (Interrogatives)',
#  24: 'number (Numbers)',
#  25: 'quant (Quantifiers)',
#  30: 'affect (Affect)',
#  31: 'posemo (Positive Emotions)',
#  32: 'negemo (Negative Emotions)',
#  33: 'anx (Anx)',
#  34: 'anger (Anger)',
#  35: 'sad (Sad)',
#  40: 'social (Social)',
#  41: 'family (Family)',
#  42: 'friend (Friends)',
#  43: 'female (Female)',
#  44: 'male (Male)',
#  50: 'cogproc (Cognitive Processes)',
#  51: 'insight (Insight)',
#  52: 'cause (Causal)',
# ...

# %%
liwc
# Out:
# {'beachward': [111],
#  'momento': [100, 103],
#  'convincedly': [50, 51],
#  'warfare': [30, 32, 34, 80, 83, 115],
#  'empathized': [80, 81],
#  'coffeehouses': [70, 74, 111],
#  'reeky': [30, 32, 60],
#  'sincerest': [30, 31],
#  'fleeing': [20, 80, 85, 100, 101],
#  'respectfully': [30, 31, 80, 83],
#  'curioso': [50, 51],
#  'rentes': [112, 113],
#  'debituminization': [113],
#  'drinking': [70, 74, 111],
#  'chatino': [40, 80, 81, 111],
#  'frightfulness': [30, 32, 33],
#  'mucous': [70, 71],
#  'respondents': [40],
#  'vigilantes': [80, 85],
#  'logicist': [50, 51],
#  'contradictional': [30, 32, 34, 40],
#  'god': [80, 83, 114],
#  'insomniac': [70, 72],
#  'chieftainry': [80, 83],
#  'cycledom': [100, 103],
#  'nurturant': [30, 31],
#  'behaviourally': [100, 101],
#  'straighter': [21, 22, 100, 102],
#  'roughest': [21, 22, 60, 63],
#  'glamorous': [30, 31],
#  'incapableness': [80, 82, 83],
#  'blisses': [30, 31],
#  'disheartenedly': [30, 32, 35],
# ...

# %%
len(liwc)
# Out:
# 34631

# %%
'college' in liwc
# Out:
# True

# %%
'like' in liwc
# Out:
# True

# %%
'friend' in liwc
# Out:
# True

# %%
'gpa' in liwc
# Out:
# True

# %%
liwc['gpa']
# Out:
# [80, 82, 110]

# %%
for cid in liwc['gpa']:
    print(int_cate[cid])
# Out:
# drives (Drives)
# achieve (Achievement)
# work (Work)
